# %% [markdown]
# # EOLES Hands-on

# %%
import pandas as pd

vre_profiles_2006_data = pd.read_csv("inputs/vre_profiles2006.csv", index_col=[0,1], squeeze=True, header=None)
vre_profiles_2006_data.head()
# Out:
# 0         1
# offshore  0    0.865143
#           1    0.880000
#           2    0.880000
#           3    0.873429
#           4    0.852000
# Name: 2, dtype: float64

# %% [markdown]
# ### Imports

# %%
import pandas as pd 
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (22,5)
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# ### Load Data

# %%
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
vre_profiles_2006_data = pd.read_csv("inputs/vre_profiles2006.csv", names=["Type", "Hour", "Production Profile"])
vre_profiles_2006_data = vre_profiles_2006_data.pivot(index='Hour', columns='Type')
# Preview the first 5 lines of the loaded data 
vre_profiles_2006_data.describe()
# Out:
#       Production Profile
# Type            offshore      onshore           pv
# count        8760.000000  8760.000000  8760.000000
# mean            0.525416     0.324709     0.162328
# std             0.259725     0.173192     0.222457
# min             0.017429     0.027760     0.000000
# 25%             0.311143     0.190543     0.000000
# 50%             0.521571     0.295253     0.003427
# 75%             0.747321     0.435025     0.319898
# max             0.991143     0.931505     0.815044

# %%
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
demand_2006_data = pd.read_csv("inputs/demand2006.csv", names=["Hour", "Demand"])
# Preview the first 5 lines of the loaded data 
demand_2006_data.head()
# Out:
#    Hour  Demand
# 0     0  60.891
# 1     1  63.093
# 2     2  63.472
# 3     3  61.353
# 4     4  57.860

# %%
def plotProfile(profileName):
    f, ax = plt.subplots()
    ax.plot(vre_profiles_2006_data["Production Profile"][profileName])
    ax.set(xlabel='Hour', ylabel='Production profile', title=profileName + 'Offshore electricity – Yearly production profile')
    ax.grid()
    mean=vre_profiles_2006_data["Production Profile"][profileName].mean()
    plt.axhline(mean, color='r', linestyle='--')
    plt.legend(['Production', 'Mean'])
    plt.ylim(0, 1)
    plt.show()

# %%
def plotDemand():
    f, ax = plt.subplots()
    ax.plot(demand_2006_data['Hour'], demand_2006_data['Demand'])
    ax.set(xlabel='Hour', ylabel='Demand',
       title='Electricity Demand (2006)')
    ax.grid()
    plt.show()

# %%
plotProfile('onshore')
plotProfile('offshore')
plotProfile('pv')
plotDemand()
